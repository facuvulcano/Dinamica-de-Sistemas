# %% [markdown]
# # <font color='red'>Sistemas Dinámicos Autónomos</font>
#
# #### **Definición:**
#
# Un sistema autónomo es aquel cuya evolución depende únicamente de su estado actual, no del tiempo de manera explícita. Las ecuaciones diferenciales que describen un sistema autónomo no contienen el tiempo como variable independiente.
#
# #### **Ecuación General:**
#
# $$
# \frac{\partial x}{\partial t} = f(x)
# $$
#
# - Aquí, el cambio en el estado 𝑥 con el tiempo depende solo de la función 𝑓(𝑥), que es una función del estado actual.
#
# #### **Importancia:**
#
# Los sistemas autónomos se utilizan para modelar fenómenos donde las reglas del comportamiento del sistema no cambian con el tiempo.
#
# # <font color='red'>Sistemas Lineales e Invariantes en el Tiempo (LTI)</font>
#
# #### **Definición:**
#
# Un sistema LTI es aquel que es lineal (cumple con los principios de superposición y homogeneidad) e invariante en el tiempo (su comportamiento no cambia con el tiempo).
#
# #### **Linealidad:**
#
# Si $x_1(t)$ y $x_2(t)$ son soluciones del sistema, entonces cualquier combinacion lineal $a * x_1(t) + b * x_2(t)$ tambien es solucion
#
# #### **Invariancia en el Tiempo:**
#
# Las propiedades del sistema y su respuesta a cualquier entrada son las mismas, sin importar cuándo se aplique la entrada.
#
# #### **Ecuación para un Sistema LTI:**
#
# $X' = AX$
#
# Donde $X$ es el vector de estado y $A$ es una matriz de coeficientes constantes que define la dinamica del sistema.
#
# # <font color='red'>**Relación entre Sistemas Autónomos y LTI:**</font>
#
# #### **Definicion**:
#
# Un sistema autónomo LTI es un caso especial de sistemas LTI donde no hay entradas externas dependientes del tiempo. La evolución del sistema depende únicamente del estado actual, y la matriz
# 𝐴 describe cómo las variables de estado interactúan entre sí.
#
# #### **Ecuación de un Sistema Autónomo LTI:**
#
# $X' = AX$
#
# Es autonomo porque no depende de $t$ (tiempo) y es LTI porque es lineal e invariante en el tiempo.
#
# # <font color='red'>Sistema LTI con Entradas Externas</font>
#
# #### **Ecuación General con Entrada:**
#
# $X' = AX + Bu(t)$
#
# - $X'$: Derivada del vector de estado con respecto al tiempo
# - $A$: Matriz de coeficientes (constante)
# - $B$: Matriz que relaciona las entradas con el estado.
# - $u(t)$: Vector de entradas externas que pueden depender del tiempo.
#
# Cuando $u(t) != 0$ el sistema tiene entradas externas, lo que lo hace no autonomo. Sin embargo, sigue siendo lineal e invariante en el tiempo si las matrices $A$ y $B$ son constantes.
#
# # **Conceptos Clave**
#
# Autonomía: Dependencia solo del estado actual, no del tiempo ni de entradas externas.
# Linealidad: Relación proporcional y aditiva entre entradas y salidas.
# Invariancia en el Tiempo: Comportamiento consistente independientemente del tiempo.
#
# # **Aplicaciones y Análisis**
#
# - Los sistemas LTI (autónomos o no) son fundamentales en ingeniería y ciencias aplicadas porque son más fáciles de analizar matemáticamente.
#
# - Pueden analizarse usando técnicas como la transformada de Laplace, la función de transferencia, y métodos de estabilidad como la teoría de Lyapunov.
#
# **Conclusión**
#
# Un sistema autónomo LTI es un sistema que evoluciona de acuerdo con sus propias dinámicas internas, sin influencia externa y sin depender explícitamente del tiempo. Cuando se añade una entrada externa
# 𝑢
# (
# 𝑡
# )
# u(t), el sistema sigue siendo lineal e invariante en el tiempo, pero ya no es autónomo. Estos conceptos son fundamentales en el análisis y diseño de sistemas dinámicos, especialmente en campos como la ingeniería de control, física, economía, y biología.

# %% [markdown]
# En el contexto de sistemas dinámicos, un sistema autónomo es un tipo de sistema donde las reglas que gobiernan la evolución del sistema en el tiempo no dependen explícitamente del tiempo. En otras palabras, las ecuaciones diferenciales o de diferencias que describen el sistema no incluyen el tiempo como una variable independiente.
#
# #### <font color='yellow'>**Características de los sistemas autónomos:**</font>
#
# **Independencia del tiempo:** En un sistema autónomo, las leyes del sistema son las mismas en cualquier instante de tiempo. Esto significa que la forma en que el sistema cambia de estado solo depende de su estado actual y no del tiempo en el que se encuentra.
#
# **Ecuaciones diferenciales autónomas:** Las ecuaciones que describen un sistema autónomo suelen tener la forma general:
#
# $$
# \frac{\partial x}{\partial t} = f(x)
# $$
#
# - Donde $x$ es el vector de estado del sistema y $f(x)$ es una funcion del estado de sistema que determina la dinamica del sistema. No hay uan dependencia del tiempo $t$ en la funcion $f(x)$.
#
# **Estabilidad y puntos de equilibrio:** Los sistemas autónomos suelen analizarse en términos de la estabilidad de sus puntos de equilibrio. Un punto de equilibrio es un estado donde, si el sistema comienza allí, permanecerá allí indefinidamente (es decir,  $\frac{\partial x}{\partial t} = 0$). Se estudia la estabilidad de estos puntos para entender cómo se comportará el sistema en su proximidad.
#
# **Aplicaciones:** Los sistemas autónomos son comunes en muchas áreas de la ciencia y la ingeniería, incluyendo la biología, la ecología, la economía, y la física. Por ejemplo, el modelo de depredador-presa de Lotka-Volterra es un sistema autónomo que describe la interacción entre dos especies en un ecosistema.

# %% [markdown]
# Si tienes sistemas autónomos LTI (Lineales e Invariantes en el Tiempo), te estás refiriendo a una clase específica de sistemas dinámicos que tienen las siguientes características:
#
# #### <font color='yellow'>**Características de los Sistemas Autónomos LTI:**</font>
#
# **Autonomía:** Como mencionamos anteriormente, un sistema autónomo es aquel en el que las ecuaciones que describen la evolución del sistema no dependen explícitamente del tiempo. Esto significa que el sistema cambia su estado únicamente en función de su estado actual y no de manera explícita por la hora o el instante en el que se encuentre.
#
# **Linealidad:** Un sistema es lineal si cumple con los principios de superposición y homogeneidad. Esto significa que si $x_1(t) y $x_2(t) son soluciones del sistema, cualquier combinacion lineal de estas, $ax_1(t) + bx_2(t)$ (donde a y b son constantes), tambien es una solucion del sistema.
#
# La linealidad implica que las ecuaciones diferenciales que describen el sistema son ecuaciones diferenciales lineales. Por ejemplo, un sistema de ecuaciones diferenciales lineales de primer orden puede escribirse como:
#
# $$
# \frac{\partial x(t)}{\partial t} = Ax(t)
# $$
#
# donde $x(t)$ es un vector de estados y A es una matriz de coeficientes constantes.
#
# **Invarianza en el tiempo (Time-Invariant, TI):** Un sistema es invariante en el tiempo si sus propiedades no cambian con el tiempo. Esto significa que su comportamiento es el mismo, independientemente del momento en el que se analice. Para un sistema descrito por una ecuación diferencial, esto implica que los coeficientes de la ecuación diferencial no cambian con el tiempo.
#
# En términos prácticos, un sistema invariante en el tiempo responde de la misma manera a una entrada específica, sin importar cuándo se aplique esa entrada
#
# #### **Importancia de los Sistemas Autónomos LTI:**
#
# - Facilidad de Análisis: Los sistemas LTI son más fáciles de analizar que los sistemas no lineales o variantes en el tiempo. Tienen propiedades matemáticas bien definidas que permiten el uso de técnicas como la transformada de Laplace, la función de transferencia, la respuesta en frecuencia, etc.
#
# - Respuesta a Señales: Se puede prever la respuesta de un sistema LTI a cualquier señal de entrada mediante la convolución con la respuesta impulsiva del sistema.
#
# - Estabilidad y Control: En ingeniería de control, los sistemas LTI son fundamentales para el diseño de controladores y el análisis de estabilidad.
#
# En resumen, un sistema autónomo LTI es un tipo de sistema lineal cuya dinámica no depende explícitamente del tiempo y cuyas características y comportamiento no cambian con el tiempo. Esto lo hace particularmente útil para análisis matemático y aplicaciones de ingeniería.

# %% [markdown]
# $X' = AX + Bu(t)$ es una representación estándar de un sistema dinámico lineal en el dominio del tiempo. Vamos a desglosar esta ecuación y relacionarla con las características de los sistemas autónomos LTI (Lineales e Invariantes en el Tiempo)
#
# #### **Descomposicion de la ecuacion:**
#
# 1- $X$: Es el vector de estado del sistema. Representa las variables del sistema que cambian con el tiempo. Si el sistema tiene $n$ variables de estado, entonces $X$ es un vector columna de dimension $n X 1$.
#
# 2- $X'$ o $\frac{partial X}{partial t}$: Es la derivada del vector de estado con respecto al tiempo. Indica como cambia el estado del sistema con el tiempo.
#
# 3- $A$: Es una matriz de coeficientes de tamanio n x n. Esta matriz define la dinamica interna del sistema, es decir, como las variables de estado se relacionan entre si. Para un sistema LTI, esta matriz es constante en el tiempo, reflejando la linealidad y la invarianca en el tiempo del sistema.
#
# 4- $B$: Es una matriz de coeficientes de tamanio n $n x m$, donde m es el numero de entradas del sistema. Esta matriz define como la entrada $u(t)$ afecta al sistema.
#
# 5- $u(t)$: Es el vector de entrada de dimension $m x 1$. Representa las entradadas externas o fuerzas aplicadas al sistema que pueden depender del tiempo.
#
# #### **Relaciones con sistemas autonomos LTI:**
#
# Un sistema utonomo LTI es un caso especial de la ecuacion general proporcionada. En un sistema autonomo, no hay entradas que varien con el tiempo. Es decir, $u(t) = 0$ para todos los $t$. Cuando $u(t)$ = 0, la ecuacion se reduce a:
# $$
# X' = AX
# $$
# Esta forma es precisamente la de un sistema autónomo LTI, donde la evolución del sistema depende solo de su estado actual 𝑋 y no hay dependencia explícita del tiempo ni entradas externas que cambien con el tiempo.
#
# #### Efecto de la entrada $Bu(t)$:
#
# Cuando la entrada $u(t) != 0$, el sistema ya no es autonomo porque su evoliucion depende de las entradas externas que pueden variar con el tiempo. Sin embargo, el sistema sigue siendo lineal e invariante en el tiempo si las matrices A y B son constantes.
#
# En este caso, el termino $Bu(t)$ representa como las entradas afectan la tasa de cambio del estado. Esto permite al sistema responder a entradas externas de manera predecible. Las caracteristicas de linealidad e invariancia en el tiempo permiten analizar el sistem utilizando tecnicas como la transformada de Laplace o el analisis de funciones de transferencia.
#
# Resumen:
#
# - Sistema Autonomo LTI: $X' = AX$ (sin entradas externas; la evolucion depende solo del estado actual)
#
# - Sistema No autonomo LTI con Entradas: $X' = AX + Bu(t) (con entradas externas; la evolucion depende del estado actual y de las entradas que pueden variar con el tiempo).
#
# Ambas formas son lineales e invariantes en el tiempo si las matrices 𝐴 y B son constantes, lo que permite utilizar una amplia gama de técnicas matemáticas para su análisis y diseño en ingeniería de control y otras aplicaciones.

# %% [markdown]
# Los autovalores (eigenvalues) y autovectores (eigenvectors) son conceptos fundamentales en el análisis de sistemas dinámicos lineales, especialmente en el contexto de sistemas autónomos LTI (Lineales e Invariantes en el Tiempo). Veamos cómo se relacionan estos conceptos y por qué son importantes:
#
# #### **Relacion con Sistemas Autonomos LTI**
#
# Para un sistema autonomo LTI descrito por la ecuacion diferencial:
# $$
# X' = AX
# $$
#
# Donde
#
# - $X$ es el vector de estado
# - $A$ es una matriz de coeficientes de tamanio $n x n$
#
# El comportamiento del sistema a lo largo del tiempo está determinado por la matriz 𝐴 Los autovalores y autovectores de A proporcionan información crítica sobre la dinámica del sistema.
#
# #### **Autovalores y autovectores: Definicion y proposito**
#
# - Autovalores (λ): Un autovalor de la matriz A es un numero que satisface la ecuacion caracteristica:
# $$
# det(A - λI) = 0
# $$
# Donde I es la matriz identidad de tamanio $n x n$. Los autovalores indican como se estiran o comprimen los autovectores asociados a lo largo de cada direccion en el espacio de estado.
#
# - Autovectores ($v$): Un autovector correspondiente a un autovalor λ es un vector no nulo que satisface la ecuacion:
# $$
# Av = λv
# $$
# Los autovectores representan las direcciones en el espacio del estado a lo largo de las cuales el sistema experimenta crecimiento o decrecimiento exponencial.
#
# #### **Importancia de Autovalores y Autovectores en Sistemas Dinámicos**
#
# **Estabilidad del Sistema:**
#
# - La estabilidad de un sistema autónomo LTI está determinada por los autovalores de la matriz 𝐴
#
# - Si todos los autovalores tienen partes reales negativas, el sistema es estable asintóticamente, lo que significa que las soluciones convergerán al punto de equilibrio en el tiempo.
#
# - Si algún autovalor tiene una parte real positiva, el sistema es inestable, y las soluciones se alejarán del punto de equilibrio.
#
# - Si todos los autovalores tienen partes reales cero (y no hay parte imaginaria), el sistema es marginalmente estable.
#
# **Comportamiento dinamico:**
#
# - Los autovalores también determinan la naturaleza del comportamiento dinámico del sistema. Por ejemplo, autovalores complejos con partes reales negativas indican un comportamiento oscilatorio amortiguado, mientras que autovalores reales negativos indican un decaimiento exponencial sin oscilaciones.
#
# - La magnitud de la parte real de los autovalores indica la velocidad con la que el sistema se estabiliza o se vuelve inestable.
#
# **Modos propios del sistema:**
#
# - Los autovectores de A definen los modos propios del sistema. Cada modo propio corresponde a un comportamiento específico del sistema, ya sea oscilatorio o exponencial, dependiendo de los autovalores.
#
# - Las soluciones del sistema pueden expresarse como combinaciones lienales de estos modos propios. Si $X(t)$ es una solucion del sistema, entonces pueden escribirse como:
#
# $$
# X(t) = c_1e^{λ_1t}v1 + c_2e^{λ_2t}v2 + .... + c_ne^{λnt}vn
# $$
# Donde $c_i$ son constantes determiandas por las condiciones iniciales, $λ_i$ son los autovalores, y $v_i$ son los autovectores.
#
# #### **Aplicaciones Prácticas**
#
# **Análisis de Control:** En ingeniería de control, el análisis de autovalores es esencial para diseñar sistemas estables. Los ingenieros ajustan los parámetros del sistema (es decir, los elementos de la matriz A) para asegurar que los autovalores tengan las propiedades deseadas (por ejemplo, partes reales negativas para estabilidad).
#
# **Respuesta Natural del Sistema:** En sistemas eléctricos, mecánicos, y otros sistemas físicos, los autovalores y autovectores ayudan a describir la respuesta natural del sistema ante condiciones iniciales, sin entradas externas.
#
# **Modelado y Simulación:** En simulaciones de sistemas dinámicos, los autovalores proporcionan información sobre cómo ajustar los modelos para capturar mejor la dinámica observada en el mundo real.
#
# Resumen
#
# Los autovalores y autovectores de la matriz A son herramientas fundamentales para comprender y analizar el comportamiento de sistemas autónomos LTI. Los autovalores indican la estabilidad y el tipo de respuesta dinámica (crecimiento, decaimiento, oscilación), mientras que los autovectores muestran las direcciones específicas en el espacio del estado donde ocurren estos comportamientos. Juntos, permiten una comprensión profunda de la dinámica del sistema y son esenciales en el diseño y control de sistemas en muchas áreas de la ingeniería y las ciencias.
